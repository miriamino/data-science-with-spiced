# %%
import pandas as pd

# %%
df = pd.read_csv('penguins_simple.csv', sep=';')
df
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    Adelie                39.1               18.7                181.0
# 1    Adelie                39.5               17.4                186.0
# 2    Adelie                40.3               18.0                195.0
# 3    Adelie                36.7               19.3                193.0
# 4    Adelie                39.3               20.6                190.0
# ..      ...                 ...                ...                  ...
# 328  Gentoo                47.2               13.7                214.0
# 329  Gentoo                46.8               14.3                215.0
# 330  Gentoo                50.4               15.7                222.0
# 331  Gentoo                45.2               14.8                212.0
# 332  Gentoo                49.9               16.1                213.0
#
#      Body Mass (g)     Sex
# 0           3750.0    MALE
# 1           3800.0  FEMALE
# ...

# %% [markdown]
# Species: categorical variables, string
# Culmen Length/Depth, Flipper Length, Body Mass: metric variables, float
# Sex: categorical variables, string

# %%
female = df.Sex=='FEMALE'
male = df.Sex=='MALE'
df.corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000          -0.228626
# Culmen Depth (mm)             -0.228626           1.000000
# Flipper Length (mm)            0.653096          -0.577792
# Body Mass (g)                  0.589451          -0.472016
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.653096       0.589451
# Culmen Depth (mm)              -0.577792      -0.472016
# Flipper Length (mm)             1.000000       0.872979
# Body Mass (g)                   0.872979       1.000000

# %%
adelie = df.Species=='Adelie'
df[adelie].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.385813
# Culmen Depth (mm)              0.385813           1.000000
# Flipper Length (mm)            0.332274           0.310897
# Body Mass (g)                  0.544276           0.580156
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.332274       0.544276
# Culmen Depth (mm)               0.310897       0.580156
# Flipper Length (mm)             1.000000       0.464854
# Body Mass (g)                   0.464854       1.000000

# %%
df[female&adelie].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.160636
# Culmen Depth (mm)              0.160636           1.000000
# Flipper Length (mm)           -0.037240           0.064044
# Body Mass (g)                  0.170095           0.396937
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)             -0.037240       0.170095
# Culmen Depth (mm)               0.064044       0.396937
# Flipper Length (mm)             1.000000       0.262930
# Body Mass (g)                   0.262930       1.000000

# %%
df[male&adelie].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000          -0.038247
# Culmen Depth (mm)             -0.038247           1.000000
# Flipper Length (mm)            0.313488           0.185328
# Body Mass (g)                  0.220370           0.159558
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.313488       0.220370
# Culmen Depth (mm)               0.185328       0.159558
# Flipper Length (mm)             1.000000       0.360434
# Body Mass (g)                   0.360434       1.000000

# %%
gentoo = df.Species=='Gentoo'
df[gentoo].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.654023
# Culmen Depth (mm)              0.654023           1.000000
# Flipper Length (mm)            0.664205           0.710642
# Body Mass (g)                  0.666730           0.722967
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.664205       0.666730
# Culmen Depth (mm)               0.710642       0.722967
# Flipper Length (mm)             1.000000       0.711305
# Body Mass (g)                   0.711305       1.000000

# %%
df[female&gentoo].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.430444
# Culmen Depth (mm)              0.430444           1.000000
# Flipper Length (mm)            0.206881           0.307793
# Body Mass (g)                  0.271926           0.371881
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.206881       0.271926
# Culmen Depth (mm)               0.307793       0.371881
# Flipper Length (mm)             1.000000       0.487618
# Body Mass (g)                   0.487618       1.000000

# %%
df[male&gentoo].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.306767
# Culmen Depth (mm)              0.306767           1.000000
# Flipper Length (mm)            0.520438           0.470975
# Body Mass (g)                  0.391310           0.253457
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.520438       0.391310
# Culmen Depth (mm)               0.470975       0.253457
# Flipper Length (mm)             1.000000       0.330452
# Body Mass (g)                   0.330452       1.000000

# %%
chinstrap = df.Species=='Chinstrap'
df[chinstrap].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.653536
# Culmen Depth (mm)              0.653536           1.000000
# Flipper Length (mm)            0.471607           0.580143
# Body Mass (g)                  0.513638           0.604498
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.471607       0.513638
# Culmen Depth (mm)               0.580143       0.604498
# Flipper Length (mm)             1.000000       0.641559
# Body Mass (g)                   0.641559       1.000000

# %%
df[female&chinstrap].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.256317
# Culmen Depth (mm)              0.256317           1.000000
# Flipper Length (mm)            0.121909           0.135474
# Body Mass (g)                  0.275594           0.391344
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.121909       0.275594
# Culmen Depth (mm)               0.135474       0.391344
# Flipper Length (mm)             1.000000       0.242150
# Body Mass (g)                   0.242150       1.000000

# %%
df[male&chinstrap].corr()
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000           0.446270
# Culmen Depth (mm)              0.446270           1.000000
# Flipper Length (mm)            0.169109           0.421323
# Body Mass (g)                  0.238285           0.345404
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.169109       0.238285
# Culmen Depth (mm)               0.421323       0.345404
# Flipper Length (mm)             1.000000       0.664588
# Body Mass (g)                   0.664588       1.000000
