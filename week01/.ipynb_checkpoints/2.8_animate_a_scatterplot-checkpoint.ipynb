# %% [markdown]
# #### Step 1
# Load the file data/gapminder_total_fertility.csv into pandas.

# %%
import pandas as pd

# %%
fert = pd.read_csv('data/gapminder_total_fertility.csv', index_col=0)
fert.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %% [markdown]
# #### Step 2
# Proceed in the same way with the file data/gapminder_lifeexpectancy.xlsx. Save it in a DataFrame with the name life.Use the function pandas.read_excel() to read in the excel file.

# %%
life = pd.read_excel('data/gapminder_lifeexpectancy.xlsx', index_col=0)
life.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# ...

# %% [markdown]
# #### Step 3
# Check whether both tables have the same size and shape.

# %%
print(life.shape)
print(fert.shape)
# Out:
# (260, 217)
# (260, 216)

# %% [markdown]
# If they don’t, it is not a problem. It is just good practice to check.

# %% [markdown]
# #### Step 4
# Take a look at the columns of both tables:

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %% [markdown]
# and

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %% [markdown]
# One table has columns as strings, the other has integer numbers. To merge the tables, we need to convert both into the same format:

# %%
fert.columns = fert.columns.astype(int)

# %% [markdown]
# Check with fert.columns whether the transformation was successful.

# %%
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %% [markdown]
# #### Step 5
# Now, let’s check the row index of the table:

# %%
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='Total fertility rate', length=260)

# %% [markdown]
# The name of the index should be called country. You can change it with:

# %%
fert.index.name = 'country'

# %%
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='country', length=260)

# %%
life.index.name = 'country'
life.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'South Sudan'],
#       dtype='object', name='country', length=260)

# %% [markdown]
# #### Step 6
# Now convert the table into long format. First, we have to move the row index into a column:

# %%
fert = fert.reset_index()
fert
# Out:
#                    country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0                 Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2    Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                  Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                  Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255             Yugoslavia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256                 Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 257               Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# 258                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
life = life.reset_index()
life
# Out:
#                    country   1800   1801   1802   1803   1804   1805   1806  \
# 0                 Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1              Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2    Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                  Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                  Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ..                     ...    ...    ...    ...    ...    ...    ...    ...
# 255             Yugoslavia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 256                 Zambia  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# 257               Zimbabwe  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# 258                  Åland    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 259            South Sudan  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %% [markdown]
# Second, we use the convenient melt function for the conversion:

# %%
fert = fert.melt(id_vars='country', var_name='year', value_name='fertility_rate')
fert
# Out:
#                      country  year  fertility_rate
# 0                   Abkhazia  1800             NaN
# 1                Afghanistan  1800            7.00
# 2      Akrotiri and Dhekelia  1800             NaN
# 3                    Albania  1800            4.60
# 4                    Algeria  1800            6.99
# ...                      ...   ...             ...
# 56155             Yugoslavia  2015             NaN
# 56156                 Zambia  2015            5.59
# 56157               Zimbabwe  2015            3.35
# 56158                  Åland  2015             NaN
# 56159                  Åland  2015             NaN
#
# [56160 rows x 3 columns]

# %%
life = life.melt(id_vars='country', var_name='year', value_name='life_expectancy')
life
# Out:
#                      country  year  life_expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %% [markdown]
# #### Step 7
# Repeat the steps above to add data from the file data/gapminder_population.xlsx.

# %%
population = pd.read_excel('data/gapminder_population.xlsx', index_col=0)
population.columns
population.index.name = 'country'
population = population.reset_index()
population
# Out:
#                                           country       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# ...

# %%
population = population.melt(id_vars='country', var_name='year', value_name='population')
population
# Out:
#                                             country  year  population
# 0                                          Abkhazia  1800         NaN
# 1                                       Afghanistan  1800   3280000.0
# 2                             Akrotiri and Dhekelia  1800         NaN
# 3                                           Albania  1800    410445.0
# 4                                           Algeria  1800   2503218.0
# ...                                             ...   ...         ...
# 22270                             Northern Marianas  2015         NaN
# 22271  South Georgia and the South Sandwich Islands  2015         NaN
# 22272                     US Minor Outlying Islands  2015         NaN
# 22273                                Virgin Islands  2015         NaN
# 22274                                     West Bank  2015         NaN
#
# [22275 rows x 3 columns]

# %% [markdown]
# #### Step 8
# Now we can glue the data frames together. This works great with the merge function:

# %%
df = fert.merge(population)
df = df.merge(life)
df
# Out:
#                      country  year  fertility_rate  population  \
# 0                   Abkhazia  1800             NaN         NaN
# 1                Afghanistan  1800            7.00   3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN         NaN
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# ...                      ...   ...             ...         ...
# 20974             Yugoslavia  2015             NaN         NaN
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
# 20977                  Åland  2015             NaN         NaN
# 20978                  Åland  2015             NaN         NaN
#
#        life_expectancy
# 0                  NaN
# 1                28.21
# 2                  NaN
# 3                35.40
# 4                28.82
# ...                ...
# 20974              NaN
# ...

# %%
co2 = pd.read_csv('data/yearly_co2_emissions_1000_tonnes.csv', index_col=0)
co2.columns = co2.columns.astype(int)
co2 = co2.reset_index()
co2 = co2.melt(id_vars='country', var_name='year', value_name='co2_emissions')
df = df.merge(co2)
df
# Out:
#            country  year  fertility_rate  population  life_expectancy  \
# 0      Afghanistan  1800            7.00   3280000.0            28.21
# 1          Albania  1800            4.60    410445.0            35.40
# 2          Algeria  1800            6.99   2503218.0            28.82
# 3          Andorra  1800             NaN      2654.0              NaN
# 4           Angola  1800            6.93   1567028.0            26.98
# ...            ...   ...             ...         ...              ...
# 15223    Venezuela  2015            2.34  31108083.0            74.80
# 15224      Vietnam  2015            1.70  93447601.0            75.40
# 15225        Yemen  2015            3.83  26832215.0            66.00
# 15226       Zambia  2015            5.59  16211767.0            56.70
# 15227     Zimbabwe  2015            3.35  15602751.0            59.30
#
#        co2_emissions
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# ...

# %%
cumco2 = pd.read_csv('data/cumulative_co2_emissions_tonnes.csv', index_col=0)
cumco2.columns = cumco2.columns.astype(int)
cumco2 = cumco2.reset_index()
cumco2 = cumco2.melt(id_vars='country', var_name='year', value_name='cum_co2_emissions')
df = df.merge(cumco2)

# %% [markdown]
# #### Step 9
# Now you can select specific columns and plot them:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df_subset = df.loc[df['country'].isin(['France', 'Germany', 'Sweden'])]
sns.lineplot(x='year', y='life_expectancy', hue='country',
            data=df_subset)

# %% [markdown]
# You can also produce a scatterplot:

# %%
sns.scatterplot(x='year', y='life_expectancy', hue='country',
            data=df_subset, alpha=0.6)

# %% [markdown]
# #### Step 10
# To create an animated scatterplot showing the correlation between life expectancy and fertility, create one plot for each year between 1960 and 2015 (before that, the data contains too many gaps).

# %% [markdown]
# Save each scatterplot to a separate file containing the year in the filename, e.g. lifeexp_1999.png .

# %% [markdown]
# Hint Use the function plt.axis((xmin, xmax, ymin, ymax)) to fix the coordinates of the plot.

# %% [markdown]
# #### Step 11
# Adjust the plot, so that the size of the symbols represents the population from the gapminder dataset.

# %% [markdown]
# #### Step 12
# Install the Python module imageio, by typing in the terminal:

# %% [markdown]
# Adjust the following code example and execute it:

# %%
import imageio
import os

images = []

folder = 'images'

if not os.path.exists(folder):
    os.mkdir(folder)

# %%
pop_min = df['population'].min()
pop_max = df['population'].max()
pop_min

co2_min = df['cum_co2_emissions'].min()
co2_max = df['cum_co2_emissions'].max()/2

# %%
for year in range(1960, 2016):
    p = sns.scatterplot(x='life_expectancy', 
                        y='fertility_rate', 
                        hue='cum_co2_emissions', 
                        data=df[df['year'] == year], 
                        alpha=0.6, size='population', 
                        legend=False, sizes=(50, 4000), 
                        size_norm=(pop_min, pop_max),
                        hue_norm=(co2_min, co2_max))
    plt.title(f'Year: {year}')
    p.set(xlabel='Life Expectancy', ylabel='Total Fertility Rate')
    plt.axis([25, 80, 1, 9])
    filename = f'lifeexpfert_{year}.png'
    plt.savefig(os.path.join(folder,filename))
    images.append(imageio.imread(os.path.join(folder,filename)))
    plt.figure()    
imageio.mimsave(os.path.join(folder,'output.gif'), images, fps=20)
# Out:
# <ipython-input-28-3a1cb5b7487a>:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
